# %%
# from simulator import SimuladorUrgencias  

# sim = SimuladorUrgencias()
# valores_medicos = [2, 4, 6]
# tasas_llegada = [1/2, 1/3, 1/5]
# sim.explorar_parametros(valores_medicos,tasas_llegada)
